# %%
from extract_summary_finetune.extract_summary_from_news import ExtratSummary

# %%
lstm_summary = ExtratSummary(network="lstm1",bert="swufe_bert",loss="BCEloss")

# %%
lstm_summary.summary[0]
# Out:
# '[汽车之车官方获悉，特斯拉（中国）官网针对在售的Model S(参数|询价)长续航版、Performance高性能版的价格进行了下调，调整后售价为73.39万、83.39万元，降价幅度均为2.3万续航版的ND里6'

# %%
news_content_filled=lstm_summary.news_content_filled

# %%
import re

def divide_sentences(news_content_filled:list):
    news_to_sentences=[]
    for content in news_content_filled:
        news_content = re.split(r'(\!|\?|。|！|？|\.{6}|\,|，)', content)
        news_to_sentences.append(news_content)
    return news_to_sentences

# %%
a = divide_sentences(news_content_filled)[0]

# %%
sum([len(item) for item in a])
# Out:
# 512

# %%
import numpy as np
def modify_labels(predict_label,news_content_filled):
    news_to_sentences = divide_sentences(news_content_filled)
    predict_label_modified = []
    for k in range(len(news_to_sentences)):
        sentences_length_list = [len(sentence) for sentence in news_to_sentences[k]]
        start_index = 0
        label_modified_list = []
        for i in range(len(sentences_length_list)):
            end_index = start_index + sentences_length_list[i]
            label_divided = list(predict_label[k][start_index:end_index])
            if sum(label_divided) > 0.5*len(label_divided):
                label_modified = [True for item in label_divided]
            elif sum(label_divided) < 0.2*len(label_divided):
                label_modified = [False for item in label_divided]
            else:
                label_modified = label_divided
            label_modified_list.extend(label_modified)
            start_index = end_index
        predict_label_modified.append(np.array(label_modified_list))
    return np.array(predict_label_modified)

# %%
pred = lstm_summary.predict_label
w = modify_labels(pred,news_content_filled)

# %%
np.sum(w == pred)
lstm_summary.
# Out:
#   Input In [10]
#     lstm_summary.
#                  ^
# SyntaxError: invalid syntax

# %%
def modify_summary(modify_labels):
        word = lstm_summary.news_to_words()
        summary = []
        for i in range(modify_labels.shape[0]):
            each_summary = ''
            for j in range(modify_labels.shape[1]):
                each_summary = each_summary + (modify_labels[i][j]*word[i][j])
            summary.append(each_summary)
        return summary

# %%
modify_summary(w)[0:5]
# Out:
# /tmp/ipykernel_935730/1810000260.py:7: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   each_summary = each_summary + (modify_labels[i][j]*word[i][j])
# ['[汽车之车我们从官方获悉，特斯拉（中国）官网针对在售的Model S(参数|询价)长续航版、Performance高性能版的价格进行了下调，调整后售价为73.39万、83.39万元，降价幅度均为2.3万元续航版的ND里6',
#  '揭秘Siri，苹果发布论文阐释语音助手设计想法就多任务处理、多语言识别等问题，苹果在论文中给出了自己不同的想法。在第一篇论文中，苹果就语音助手中的多任务处理问题进行了阐释，它指出在Siri中，唤醒处理通常需要两个步骤：AI首先必须确定输入容内',
#  '在2018年的大牛行情过后，2019年的债市将如何演绎？多位基金经理在接受记者采访时表示，去年的快速上涨收窄了债市继续上扬的空间，尤其是利率债的机会明显减少，但整体牛市的格局不会变化，今年可能处于阶段性的“牛尾行情”。基于这一判断许多基金经理将债市淘金的对象指向信用债，期望从“信用利差”中获取超额收益',
#  '记者 ，总投资921亿元的广西“信息网”基础设施建设三年大会战正式启动。据了解，今年2月份，广西发布了《“信息网”基础设施建设三年大会战实施方案》，明确全区3年计划投资921亿元，建设282个项目。4月12日，共5个“信息网”新型基础设施项目集中开工',
#  '从某种程度上来看，这是因为腾讯是一个强大的生态企业，而且有着诸多的现金奶牛业务，如我们熟悉的文娱、游戏、音乐、内容等生态，这些业务的营收太好，以至于使得腾讯广告或者说腾讯在流量变现上相对求稳。腾讯顺应大趋势，积极赋能微盟等SaaS服务商，帮助这些服务商推出更多垂直领域的SaaS解决方案。']

# %%
modify_summary(pred)[0:5]
# Out:
# /tmp/ipykernel_935730/1810000260.py:7: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   each_summary = each_summary + (modify_labels[i][j]*word[i][j])
# ['[汽车之车官方获悉，特斯拉（中国）官网针对在售的Model S(参数|询价)长续航版、Performance高性能版的价格进行了下调，调整后售价为73.39万、83.39万元，降价幅度均为2.3万续航版的ND里6',
#  '揭秘Siri，苹果发布论文阐释语音助手设计想法就多任务处理、多语言识别等问题，苹果在论文中给出了自己不同的想法。在第一论文中，苹果就语音助手中的多任务处理问题进行了阐释，它指出在Siri中，唤醒处理通常需要两个步骤：AI首先必须确定输入容内',
#  '在2018年的大牛行情过后，2019年的债市将如何演绎？多位基金经理在接受记者采访时表示，去年的快速上涨收窄了债市继续上扬的空间，尤其是利率债的机会明显减少，但整体牛市的格局不会变化，今年可能处于阶段性的“牛尾行情”。基这判断多基金经理将债市淘金的对象指向信，期望从“信用利差”中获超额收紧“信用利',
#  '记者 ，总投资921亿元的广西“信息网”基础设施建设三年大会战正式启动。据了解，今年2月份，广西发布了《“信息网”基础设施建设三年大会战实施方案》，明确全区3年计划投资921亿元，建设282个项目。4月12日，共5个“信息网”新型基础设施项目集',
#  '从某种程度上来看，这是因为腾讯是一个强大的生态企业，而且有着诸多的现金奶牛业务，如我们熟悉的文娱、游戏、音乐、内容等生态，这些业务的营收太好，以至于使得腾讯广告或者说腾讯在流量变现上相对求稳。腾讯顺应大趋势，积极赋能微盟等SaaS服务商，帮助这些服务商推出更多垂直领域的SaaS解决方案。微盟将']

# %%
import re
from zhon import hanzi


def divide_sentences2(news_content_filled:list):
    news_divide_sentences=[]
    for content in news_content_filled:
        news_content = re.findall(hanzi.sentence, content)
        news_divide_sentences.append(news_content)
    return news_divide_sentences

# %%
a = divide_sentences2(news_content_filled)
a
# Out:
# [['万元。', '秒。', '版，此次调价仅针对前面两款车型。', '万元。', '万元。', '。', '）。'],
#  ['，苹果发布论文阐释语音助手设计想法就多任务处理、多语言识别等问题，苹果在论文中给出了自己不同的想法。',
#   '。',
#   '小时的音频带有语音标签，其余均只有扬声器标签。',
#   '相比于一般训练模型去获取多个标签的思路，苹果通过将不同任务的训练数据进行级联来训练多个相关任务的模型。',
#   '在另一篇论文中，苹果还介绍了多语言演讲场景的演讲者识别系统设计——知识图谱辅助听写系统决策。',
#   '以声学子模型为例，它可以基于语音信号传输痕迹来进行预测，并且其上下文感知的预测组件考虑了各种交互上下文信号，其中上下文信号包含有关发出命令的条件信息、已安装的命令语言环境、当前选择的命令语言环境以及用户在发出请求之前是否切换命令语言环境的信息。'],
#  ['年的债市将如何演绎？',
#   '多位基金经理在接受记者采访时表示，去年的快速上涨收窄了债市继续上扬的空间，尤其是利率债的机会明显减少，但整体牛市的格局不会变化，今年可能处于阶段性的“牛尾行情”。',
#   '基于这一判断，许多基金经理将债市淘金的对象指向信用债，期望从“信用利差”中获取超额收益。',
#   '在基金经理眼里，利率债的强势上扬催生了去年的大牛市，今年信用债有可能成为债市新主角，为债基提供了结构性投资机会。',
#   '她指出，历史上的债券行情，一般以利率债为开端，此后轮动到高、中、低等级信用债，最后以垃圾债收尾。',
#   '年四季度才有所好转。',
#   '随着今年利率债的投资价值降低和宽货币效果的逐步显现，利率债和信用债的利差有望进一步压缩，信用债的票息优势会逐步体现，叠加其收益率的下行，信用债将成为今年最大的看点。',
#   '股市场开春以来的大幅上涨，也让可转债成为债基眼中的“香饽饽”。'],
#  ['亿元的广西“信息网”基础设施建设三年大会战正式启动。',
#   '个项目。',
#   '亿元。',
#   '年底竣工并投入运营，项目建成后将为广西、西南及东盟的客户提供政务云、金融云、农业云、产业云等服务及同城、异地灾备服务。',
#   '精品网。',
#   '连续覆盖。'],
#  ['从某种程度上来看，这是因为腾讯是一个强大的生态企业，而且有着诸多的现金奶牛业务，如我们熟悉的文娱、游戏、音乐、内容等生态，这些业务的营收太好，以至于使得腾讯广告或者说腾讯在流量变现上相对求稳。',
#   '解决方案。',
#   '微盟将自己的定位描述为“中国中小企业云端商业及营销解决方案提供商”，同时也是中国腾讯社交网络服务平台中小企业精准营销服务提供商。',
#   '实现与顾客的实时在线连接与触达。',
#   '市场的规模竞争优势。',
#   '业务上，微盟的竞争对手除了有赞外，还有阿里、华为、腾讯甚至是亚马逊等超级巨头，它们能够利用一年上百亿的研发费，在产品性能与场景化方面轻松击败微盟旗下产品。'],
#  ['陇西县焦家湾村建起了别具特色的民俗文化墙，激发了贫困群众脱贫信心。”',
#   '多分钟到权家湾镇焦家湾村，刚一下车就听村民说，以前因为无路无水，很多人举家迁往别处，焦家湾村一度成为全县人口最少的村。',
#   '从日常生活到传统农具，从老屋椽子到废弃菌棒，一应展品均来自村民的自愿捐赠，村民、村干部都能充当讲解员，自豪地讲述关于青瓦、胡麻秆、播种犁的故事。',
#   '“民俗文化墙的建设带来的是整个村庄环境面貌的转变，村民都自觉把院落和房前屋后收拾整洁。”',
#   '焦家湾村焦家湾社的杨贺喜，不仅摘掉了“贫困户”的帽子，还成为致富能人，帮助村民解决养牛种菇中遇到的各种问题。',
#   '万元，计划实施种植养殖、食用菌、光伏电站等项目。'],
#  ['年）实施方案》，全文如下：。',
#   '主动提升旅游服务质量成为市场主体自觉意识，旅游服务质量基础设施更加完善，旅游服务质量提升的合力显著增强。',
#   '三、保障措施（一）加强组织领导各级文化和旅游部门要充分认识抓好旅游服务质量提升工作的重要意义，将服务质量提升纳入各级政府质量提升工作总体部署，建立健全领导机构和协调机制，加强与市场监管、公安、工信等部门协作配合，统筹推进服务质量提升工作。',
#   '（二）加强督导检查各级文化和旅游部门、执法机构要采取“四不两直”“双随机、一公开”等方式，组织开展各种形式的服务质量明查暗访活动，落实监管责任，加强督促指导。',
#   '（四）加强宣传引导要通过各类新闻媒体大力宣传党和国家质量工作方针政策，积极报道各地提升旅游服务质量的主要做法、典型案例及突出成就，营造全社会关注旅游质量、参与旅游质量提升的良好氛围。',
#   '（五）强化监督评估各级文化和旅游部门要加强对旅游服务质量监管和提升工作落实情况跟踪评估，建立评价体系，健全激励机制。'],
#  ['日，位于孔子故里山东曲阜的孔子博物馆青少年活动中心，一场别开生面的“射柳”体验活动正在举行，一群身穿汉服的小朋友看着箭稳稳地扎进靶子发出声声惊叹，已经逐渐掌握技巧的张俊轩沉稳地执箭、瞄准。',
#   '岁的张俊轩前几天在孔子博物馆官方微信公众号上看到了古代运动会的消息，便立刻报名，并接到了孔子博物馆的体验邀约，邀他来当“体验官”“建议官”。',
#   '为让青少年更好地了解清明习俗，感受传统文化魅力，孔子博物馆在清明节假期推出清明踏青季社教活动。',
#   '“古代运动会、趣味知识运动会、博物馆春季写生、《诗经》吟诵。”',
#   '孔子博物馆社会教育部负责人杨淑娟说，不论是古代运动会上展现的传统文化之美，还是趣味知识运动会上的文物问答，都是为了让文物“活”起来，传统文化“立”起来，用孩子们喜闻乐见的方式激发他们对传统文化的热爱。',
#   '由于是第一次举办针对青少年的传统节日主题活动，为让游客有更好的体验感受，孔子博物馆特意设计了此次体验活动，在游客的体验中及时收集反馈意见，不断调整完善，达到更好的活动效果，让更多人发现传统文化之美。'],
#  ['人，包括一线技工和智能制造、数据研发、算法工程师等方面高级人才岗位。',
#   '智能家电制造基地建设提上日程。',
#   '年，格兰仕正式对外宣布科技转型的战略方向和目标。',
#   '月，格兰仕发起成立的跃昉科技公司宣布正式落户顺德，主导开源芯片产业生态链建设，助推“顺德芯”、“中国芯”自主设计研发生产进程。',
#   '据了解，投资开源芯片，格兰仕更看重芯片产业生态的建设，希望扎根在顺德打造一个属于中国的开源芯片生态：一、形成一批国产自主专利的芯片，广泛赋能中国的传统制造。”',
#   '格兰仕集团董事长兼总裁梁昭贤表示，顺德村改项目为企业转型升级腾出了更多宝贵空间，作为顺德高质量发展的一分子，我们首先要从源头上确保高质量就业，确保高质量人才引进和培养，通过实实在在的创新驱动、科技驱动、人才驱动为顺德高质量发展再添一把火。'],
#  ['“党建联盟工程”助力脱贫攻坚。',
#   '今年以来，贺州市平桂区以“围绕一个目标、探索一种组织设置、搭建一批载体”为指引，大力实施“党建联盟工程”，集中联盟单位在人才、信息、资金方面的优势，助力脱贫攻坚。',
#   '多个单位党组织加入到联盟中来，通过组织联建、产业联培、公益联动等方式，整合各方资源，形成抓党建促脱贫攻坚强大合力。',
#   '万元建设集体茶厂，率先实现自主收茶、制茶，并与联盟成员单位贺州市物流商会、贺州市湖南商会等签订茶叶长期订购合同，解决茶叶销售后顾之忧。',
#   '联盟成员单位贺州市民间金融协会、贺州正丰农业公司积极发挥信息、技术优势，为大明村茶叶、油茶等土特产打通线上线下销售途经，拓宽大明村茶叶品牌销售渠道。',
#   '个。'],
#  ['公司经营管理层应当按照《证券公司和证券投资基金管理公司合规管理办法》的要求，切实履行合规管理职责，为合规总监、合规部门、合规人员履职提供充分的人力、物力、财力、技术支持和保障。',
#   '《证券公司和证券投资基金管理公司合规管理办法》第十三条规定：合规负责人应当对证券基金经营机构内部规章制度、重大决策、新产品和新业务方案等进行合规审查，并出具书面合规审查意见。',
#   '《证券公司和证券投资基金管理公司合规管理办法》第二十三条规定：证券基金经营机构各业务部门、各分支机构应当配备符合本办法第二十二条规定的合规管理人员。',
#   '《证券公司和证券投资基金管理公司合规管理办法》第二十五条规定：证券基金经营机构应当保障合规负责人和合规管理人员充分履行职责所需的知情权和调查权。',
#   '《证券公司和证券投资基金管理公司合规管理办法》第二十八条规定：证券基金经营机构应当制定合规负责人与合规管理人员的薪酬管理制度。',
#   '并具有履职胜任能力。'],
#  ['二六三网络通信股份有限公司第六届监事会第十三次会议决议公告本公司及监事会全体成员保证信息披露内容的真实、准确和完整，没有虚假记载、误导性陈述或重大遗漏。',
#   '各位监事对议案进行审核，并通过传真签字的方式将表决结果送达至本次会议记录人处进行统计。',
#   '名，会议的召开符合《中华人民共和国公司法》和《公司章程》的有关规定。',
#   '。',
#   '、第六届监事会第十三次会议决议。',
#   '监事会关于公司第六届监事会第十三次会议相关议案的审核意见。'],
#  ['认证。',
#   '用于鼻前庭样本中新型冠状病毒核衣壳蛋白抗原的定性检测和新型冠状病毒感染的辅助诊断。',
#   '用于定性检测人血清中的新型冠状病毒总中和抗体，识别已对新型冠状病毒具有适应性免疫反应的个体在近期或之前的感染情况。',
#   '疫苗完全接种后的体液免疫效果。',
#   '突变，可用于新型冠状病毒突变株感染的辅助识别和监测。',
#   '（文章来源：中国证券报·中证网）。'],
#  ['，标准值为不得使用。',
#   '号）中，也有一批次湖南省义丰祥实业有限公司生产的芝麻香油检出相同问题。',
#   '，标准值为不得使用。',
#   '公司是湖南省食用植物油产业联盟成员单位第一批授权使用“湖南菜籽油”区域公用品牌，湖南工业新兴优势生态绿色食品产业链重点企业，第一批省疫情防控重点保障物资生产企业。',
#   '质量管理体系认证、清洁生产审核，荣获湖南省质量管理奖、中国驰名商标、湖南老字号、湖南好粮油、湖南名牌产品、湖南省著名商标、国家免检产品、绿色食品认证、中国芝麻油行业十大品牌等荣誉称号。',
#   '被湖南省商务厅授予“湖南老字号”。'],
#  ['。', '。', '。', '。', '万股。', '股。'],
#  ['”钻探船缓缓从钻孔中拔出最后一根套管，新建通苏嘉甬铁路杭州湾跨海大桥完成工程地质勘探工作。',
#   '，大桥包括北、中、南三座航道桥，大桥建成后将成为全世界最长、建设标准最高的跨海高速铁路桥。',
#   '本次地质勘探是为确定大桥线路具体位置，详细查明桥址区的工程和水文地质条件。',
#   '个，比原计划提前一个半月完成。',
#   '“为了保障施工安全，我们成立了专班指导编制通航安全保障方案，针对滩涂施工存在的安全风险，指导项目部在全省范围内首次实现了‘坐滩法’施工。',
#   '小时作业，确保工程保质保量完工，为后续的初步设计及开工建设打下扎实基础。'],
#  ['开展传帮带工作近日，昭通市民政局召开中山—昭通社工支援帮扶工作座谈会，总结表彰第一批中山赴昭通社工服务队的工作，欢迎第二批新队员。',
#   '昭通市民政局、昭通市扶贫办相关负责人以及中山第一批、第二批赴昭通社工服务队全体队员参加会议。',
#   '座谈会上，第一批中山赴昭通社工服务队队员代表做了三个月工作总结并与第二批赴昭通社工队成员进行了经验交流。',
#   '随后，昭通市扶贫办、民政局分别向第二批服务队成员介绍了现时安置区居民的新变化，并向第二批中山赴昭通支援社工服务队提出工作期望，希望通过中山社工成熟经验的传帮带，让社区两委、社工与居民的联动更紧密，社区服务更能贴近群众的心声，将易地搬迁的焦虑感不断消除，通过丰富多彩的社区活动增强异地搬迁群众对社区的归属感，并改善不良的生活习惯，融入新生活。',
#   '名队员组成，到达昭通后将分两队前往昭通市的昭阳区靖安新区跨县区安置区和盐津县的水田安置区，开展安置区居民的社工服务、当地社工从业人员培训及督导等系列传帮带工作。',
#   '（文章来源：中山日报）。'],
#  ['年度铅蓄电池行业十强企业”两项大奖，并入选“中国轻工业百强企业综合榜单”。',
#   '多年的发展壮大，现已成为亚洲最大的汽车起动电池制造商和中国再生铅龙头企业之一。',
#   '月，是骆驼集团股份有限公司在华南区域集生产、仓储、配送、回收为一体的全资子公司。',
#   '近年来，骆驼集团华南蓄电池有限公司致力于为汽车主机厂和汽车维修市场提供高性能的蓄电池产品，是多家汽车生产企业的主要配套供应商。',
#   '骆驼集团华南蓄电池有限公司依托骆驼集团在蓄电池行业的先进技术和管理水平，不断加大产品和技术研发创新，现已成为华南地区最大的铅酸蓄电池生产基地。',
#   '。'],
#  ['家。',
#   '余家。',
#   '会上，国际人才合作和服务中心、人力资源服务沪港合作中心、人力资源产业基金合作等重大项目进行签约。',
#   '江苏领航人力资源服务集团有限公司为了拓展海外业务，走向国际，打造全球人力资源服务平台，从去年起多次到上海考察学习，寻找新的机遇，发现静安区可以作为公司开启国际化业务的新起点，遂计划在该区设立领航跨国大中华区总部。',
#   '与静安区人力资源和社会保障局达成共建国际人才合作与服务中心合作意向后，将共同推进搭建国际人才交流服务、教育培训及企业国际化发展服务等平台。',
#   '“我们看到了静安区‘全球服务商计划’给企业全球发展带来的鼓励与便捷，静安区已逐步成为国际化人才服务枢纽平台，是海外企业登陆中国与本土企业走向国际的重要门户。',
#   '一个月后又推出“全球服务商——人力资源服务专项计划”，在苏河湾区域打造全球人力资源服务共享中心。'],
#  ['的热潮继续深入，如何拥抱互联网大环境，依托互联网为自己的餐饮事业“添砖加瓦““锦上添花“成了令许多餐饮管理者头疼的“软肋”。',
#   '传统餐饮业的商户也在不断探寻新的转型，不但借助智能硬件终端从传统的普通门店逐渐向智慧门店转型。',
#   '也在营销上不断做出了新的突破，尤其是疫情之后，线下大环境不甚理想，线上渠道异军突起，成为了各家争抢的资源，而丰茂烤串作为餐饮头部品牌，在今年的老友节做出了大胆的尝试。',
#   '日是由丰茂烤串第二次举办老友节，老友节作为丰茂烤串一年一次的重大节日，这次老友节一改以往的大型线下布置，而是选择在短视频平台用直播的形式，做了一次传统餐饮行业的新尝试。',
#   '丰茂烤串老友节发起源自创始人尹龙哲：“你看我们的节日，有纪念爱情的七夕节，有纪念亲情的父母亲节，唯独没有纪念友谊的‘朋友节’。',
#   '老友节就是想让那些好久不见的老友们，可以重新聚在一起。',
#   '希望大家在老友节，都能邀请老朋友们来丰茂烤串参与老友节活动，感受老友节的现场氛围，与老朋友多聚聚。',
#   '“撸串”天生为友情而生，丰茂烤串则将这个事实，通过丰茂烤串老友节，如实说了出来。'],
#  ['行业首家内测合作伙伴。',
#   '位”。',
#   '服务再次升级。',
#   '云游戏的发展开“家庭场景”新赛道。',
#   '亿美元，预计未来国内大量主机游戏将会上线云游戏平台，带来增量规模。',
#   '行业的“客厅云游戏”时代。'],
#  ['公司研发的免热处理合金材料，实现了汽车零部件在一体化、大尺寸、薄壁、结构复杂和热处理易变形的新能源汽车结构件“铝代钢”材料的替代，打破了国外在该领域的产品垄断和技术封锁，实现了免热处理高性能材料的国产化。',
#   '在减少铝铸件制作成本和热处理成本的同时，对于推动汽车轻量化、节能减排和增加新能源汽车的续航能力，提升车辆安全等方面，将发挥至关重要的作用。',
#   '系统和大型集成电路的首选材料。',
#   '）产能将作为钠离子电池材料端的技术储配，实现公司多元化的产业布局。',
#   '答：公司研发制造的航空航天级特种中间合金，主要用于航空航天高温合金材料使用，产品包括钒、钽、钼、钨、锆、铪、铌等元素组成的数十种多元特种中间合金。',
#   '立中集团主营业务：铝合金车轮和中间合金类功能性合金新材料的研发、制造和销售。'],
#  ['尽管文玩市场从线下搬到了电商平台，假货仍然是文玩交易的痛点，作为文玩电商界领跑者的玩物得志和微拍堂无一幸免。',
#   '玩物得志也因售卖高仿阿玛尼手表引起热议，近日该平台风波不断，大规模裁员、藏品买卖业务暂停、被投诉拖欠商家货款等消息频出。',
#   '鉴定”三个环节进行，商家容易“浑水摸鱼”提高价格，让真心实意购买的消费者还误以为“捡漏”，实则是商家早已暗自标好的价格。',
#   '在黑猫投诉平台上输入微拍堂，可以看到投诉量达千余条，投诉理由多集中在“以次充好、售价、虚假宣传、退款难”等问题上。',
#   '陈先生由于平常喜欢文玩，就想在上面注册一个店铺，后来发现所喜欢的“木质手串”和“菩提手串”这两个类目不能正常入驻，导致无法正常开店，既然不能入驻，就联系了微拍堂客服要退还认证费，可是联系许久都没有任何回应。',
#   '中国质量万里行消费投诉平台针对次问题也联系了微拍堂，据悉针对方先生遇到的问题，微拍堂给出的回复是，经核实商品加工已影响二次销售，无法支持七天无理由退货，关于反馈质疑瓷度不符，因个人经验无法作为有效凭证。'],
#  ['为助力企业全面复工复产、提质提速，池州市贵池区以“四送一服”为抓手，紧贴企业实际需求，通过加强资金保障、落实专人帮扶、高效解决困难等措施，将各项助企政策落到实处。',
#   '万元。',
#   '为全力帮助企业解决复工复产后面临的资金紧张问题，贵池区“四送一服”双千工程领导小组成员单位结合各自职能，突出“四重一小”，及时落实各项扶持政策。',
#   '为有效帮助纺织企业解决复工后面临的“招工难”问题，贵池区区人社局专门推出主题为“助力企业复工，促进充分就业”的纺织企业用工“线下”专场招聘会。',
#   '多点发力，助力企业全面复工复产贵池区坚持战“疫”、生产两手抓，通过“四送一服”专项行动，促进企业在抓好疫情防控的基础上，全面复工复产。',
#   '户重点企业开展驻点帮扶，对未安排区级帮扶专员联系的重点企业，各镇街道、园区管委会分别安排专人联系，及时了解掌握企业疫情防控、复工复产、生产运营、项目建设、政策落实、要素需求等方面存在的困难和问题。'],
#  ['）也要入局酒业。',
#   '镇的古窖酒业。',
#   '元，封单一度近百万手。',
#   '亿市值的吉宏股份也要收购白酒了，该股主营为跨境电商和包装。',
#   '的股权，进而持有贵州省仁怀市茅台镇古窖酒业有限公司（以下简称古窖酒业）资产。',
#   '的股权。'],
#  ['当时的经验，对于现在深化多层次资本市场改革有什么借鉴意义。',
#   '在设计区分板块特色时，立足点还是以增强市场功能为重点，发挥市场在资源配置中的基础性作用，积极拓展市场覆盖范围，适应企业在不同发展阶段的融资需求和融资特点，满足经济社会发展的客观需要。',
#   '这就要求资本市场在新发展格局下，通过加快形成各层次有机联系、互为补充的市场体系，进一步在拓宽融资渠道、促进资本形成、优化资源配置、分散金融风险等方面发挥作用，更好地服务经济高质量发展的大局。',
#   '以注册制改革为抓手发挥市场价值发现功能“‘十四五’规划建议中明确提出，全面实行股票发行注册制，建立常态化退市机制，其基本运行逻辑是让发行人在符合基本发行条件的基础上，以投资者需求为导向，真实准确完整地披露信息。',
#   '从发行体制看，这些年经历了证券发行定价、审核、保荐制度，总体上始终遵循着市场化的改革方向，随着经济体制改革进程不断深化。',
#   '应当充分发挥资本市场在推动科技资本和实体经济高水平循环中的枢纽作用，加快构建多层次资本市场，鼓励发展创业投资、并购投资基金等私募股权投资，壮大创新资本总量，激发风险资本活性，打通金融资源与科技成果转化渠道，更好地服务符合国家战略的高新技术产业和战略性新兴产业。'],
#  ['年第四季度海峡西岸地区金融、旅游、健康、消费信心指数除旅游指数和健康指数有小幅度下降外，其余各项指数均有不同幅度上涨，总指数较上一季度呈上涨态势。',
#   '从环比上看，总指数、消费指数及金融指数有不同程度上涨，旅游指数和健康指数有小幅下降。',
#   '从同比上看，总指数、消费指数及金融指数高于去年同期，而旅游指数和健康指数均低于去年同期。',
#   '年中国经济总体上表现出较好的复苏态势，经济增速在全球主要经济体中继续位于前列，大大增强海西地区民众对于未来经济形势的信心。',
#   '年应适度加大宏观政策逆周期调节力度，注重做好跨周期调节：积极的财政政策要加力提效，继续保持一定支出强度，更加注重促进产业转型升级和以人为核心的城镇化，对冲经济增长下行压力。',
#   '稳健的货币政策要稳量降负，增强信贷总量增长的稳定性，引导实体经济平均融资利率下行，降低实体经济利息负担，有效应对成本推升型通胀。'],
#  ['、小鸣单车已经销声匿迹。',
#   '的确，曾经被资本捧上天的共享单车龙头最终没有走向资本市场这一步，有业内人士用“逆袭者”来形容哈啰，而当下的哈啰也不仅仅是共享单车的标签，更是提供更丰富的生活解决方案，与出行形成更高效的上下游关系。',
#   '亿用户，哈啰在共享出行的基础上，从两轮到四轮不断迭代，并在电动车、换电、以及更广阔生活服务类业务如“同城物流”、“网约车”、“团购”、“酒店”、“本地生活”等领域。',
#   '年将其战略定位调整为围绕基础出行的生活普惠平台，共享单车是其中最重要的底层业务。',
#   '美团、滴滴。',
#   '亿用户的出行习惯，利用哈啰大脑智慧系统系统，能够更好的将商户优惠与消费者需求进行匹配，在单位经济上有更低的获客成本优势和用户触达效率优势。'],
#  ['南财对话丨中国经济体制改革研究会会长彭森：政策大礼包是鼓励肯定，也要深圳自行杀出血路今年以来，中央一连串深化市场化改革和扩大开放的战略部署、改革举措密集出台。',
#   '月自贸试验区扩围，这些都体现出面对百年未有之大变局，中国坚定不移推动改革、扩大开放的决心。',
#   '个自贸试验区和深圳综合改革试点无疑将承担起在更高起点上推进改革开放、推动更高水平对外开放的使命。',
#   '日，中共十九届五中全会将召开，研究关于制定国民经济和社会发展第十四个五年规划和二〇三五年远景目标的建议。',
#   '深圳、海南等承担先行先试任务的地区应如何推动高质量发展，在哪些方面探索新路。',
#   '世纪经济报道记者专访了中国经济体制改革研究会会长、国家发展和改革委员会原副主任彭森。'],
#  ['元。', '净利润环比下跌。', '。', '元。', '。', '有助于降低成本。'],
#  ['轮融资，领投方为真格基金，老股东源码资本、不惑创投继续跟投。',
#   '轮千万级融资。',
#   '本轮融资将用于供应链、物流、销售、运营等环节的效率提升及新模式的探索，公司将继续深耕北京市场、探索最优且可复制的模式，进一步向其他城市复制扩张。',
#   '。',
#   '端工长、装修公司提供一站式产品配送服务。',
#   '在这个上游无强势品牌的大行业，相信掌上辅材团队可以持续整合和改造流通渠道和上游厂商。”',
#   '以及数据驱动供应链升级，辅材行业需要基于需求端的数据化改造，看好薛总带领队伍继续深入行业，做好区域试点，以效率优势复制全国。',
#   '在战略上，掌上辅材一方面，不断加强对用户及市场的洞察、提升供应链环节效率，驱动业务的发展。'],
#  ['大类内容，其中因“大头娃娃”事件而备受关注的“消”字号抑菌霜非法添加行为，成为严查重点。',
#   '医疗卫生机构传染病疫情报告、疫情控制、消毒隔离措施落实、医疗废物管理、病原微生物实验室生物安全管理等情况。',
#   '医疗机构依法执业情况，主要包括机构和人员资质、药品和医疗器械、医疗技术、放射诊疗、母婴保健和计划生育技术服务、职业健康检查和职业病诊断等方面情况。',
#   '职业卫生技术服务机构、放射卫生技术服务机构依法执业情况。',
#   '医疗机构资质（《医疗机构执业许可证》、人员资格、诊疗活动、健康体检）管理情况。',
#   '市场监管总局部署清理整治知名医院被冒牌问题》《医疗保障基金使用监督管理条例》数份文件，详细部署了医院“傍名”、医疗广告、医保基金使用的检查规则。'],
#  ['深圳亚联发展科技股份有限公司第五届董事会第三十三次会议决议的公告本公司及董事会全体成员保证信息披露的内容真实、准确、完整，没有虚假记载、误导性陈述或重大遗漏。',
#   '在公司会议室以通讯表决的方式举行。',
#   '名，符合《中华人民共和国公司法》和《公司章程》的有关规定。',
#   '会议由董事长王永彬先生主持，公司监事、高级管理人员列席了会议。',
#   '同意聘任余明先生为公司总经理，任期至公司第五届董事会任期届满时止。',
#   '）刊登的《关于公司总经理辞职及新聘总经理的公告》。'],
#  ['讯：。',
#   '项目特许经营协议补充协议（厨余垃圾）》（以下简称“特许经营协议”）。',
#   '亿元投资于本项目。',
#   '日召开总裁专题会议，同意投资、建设、运营温州永强生活垃圾焚烧发电厂厨余垃圾处理项目，同意设立项目公司龙湾伟明厨余再生资源有限公司负责项目实施。',
#   '亿元投资于本项目，并根据项目建设进度在出资额度内分期出资，自有资金投入与项目投资总额差额部分通过项目公司向商业银行申请贷款等借款方式解决，并由管理层签署后续融资协议。',
#   '项目特许经营协议补充协议（厨余垃圾）》签署。'],
#  ['日均新设企业的连续增长，表明市场主体开展经营活动的意愿增强，后劲十足，尤其是，在新设企业中，电子及通信设备制造业、医药制造业、信息化学品制造业等高新技术制造业蓬勃发展成为一大亮点，显示中国经济转型升级不断释放活力，为中国经济发展提供了强劲的新动能。',
#   '我国新设企业和市场主体的大量增加，体现出的不仅是相关政策及措施的有力推进，也显现中国创新能力在不断释放转化成促进经济增长的有效动能，从而提升经济硬实力。',
#   '近年来，通过对标国际一流水平，国内大力推进“放管服”改革，并聚焦市场主体关切和短板弱项，推出了大量务实有效的改革举措，力度大、精准度高、节奏快，进一步解放和发展生产力，激发了市场活力、增强内生动力、释放内需潜力，市场营商环境不断优化，促进经济社会持续健康发展。',
#   '年成为吸收外资最多的发展中国家，充分表明中国经济的软实力。',
#   '市场主体的持续增长必然提供更多社会就业岗位，成为提升社会成员收入增长和幸福感提升的有力保障。',
#   '从社会就业增长到收入增加，再到消费促进并形成对经济的拉动，新设企业增长成为这一最终结果的起点，为经济增长提供持续的保障。'],
#  ['。',
#   '。',
#   '项目交付成果初现。',
#   '申报并成功取得临床试验批件。',
#   '临床试验批件。',
#   '公司表示，优秀的交付记录及良好的早期项目储备为更大规模生产订单的承接提供基础。'],
#  ['黑龙江中兵矿业还在起诉中称：“弘康人寿开业至今未召开股东大会，股东对经营情况不甚了解，弘康人寿受到神秘实际控制人操纵，使用持有至到期对外投资清偿债务，不但大部分难以收回，其余部分还被弘康人寿管理层安排挪用作为新增注册资本，投资面临巨大风险。',
#   '年第二季度偿付能力报告开始，弘康人寿的实际控制人一栏变更为董事长卢德之。',
#   '月前任董事长张东武到任，进行增资扩股、经营和管理体制改革才实现盈利。',
#   '凭借第二大股东的身份，永安财险的总裁之职长期都由复星集团指派，此次却被董事会解除了职务。',
#   '尽管复星集团在官网发布关于永安保险近期情况的说明，解释蒋明的退出主要是因为年龄原因，但一位接近永安财险的人士对时代周报记者表示：“蒋明被解除职务有点蹊跷，（董事会内部）存在严重的不同意见。',
#   '年底，保监会下发“关于要求安华公司依法合规开展增资工作的函”，要求其退还相关股东增资资金，暂停股东中科恒源科技、陕西佳乐紫光科贸的增资权利，不得参与安华保险公司后续增资事宜，限制股东行使“公司股东优先购买权可以转让”的权利。'],
#  ['亿美元。',
#   '家合并的传言。”',
#   '音乐、酷狗音乐、酷我音乐的整合和管理方式。',
#   '音乐、酷狗音乐、酷我音乐等是打包好了再一起上市，而斗鱼直播、虎牙直播本身目前已各自上市，再整合的难度要大得多。',
#   '强敌环伺的游戏直播领域值得注意的是，毋庸置疑的是，斗鱼直播和虎牙直播一直都占据游戏直播行业的前两位。”',
#   '相反快手的流量大，对整个行业提升是非常有利的。'],
#  ['。',
#   '宁德时代占据了全国新能源车型配套电池的半壁江山。',
#   '。',
#   '化学、松下电器。',
#   '亿元（不含本数）或等值币种。',
#   '的总股本占比，成为先导智能第二大股东。'],
#  ['政务服务中心开展日常监督检查时，发现有个别员工存在工作时间擅自离岗的问题，目前该话务员已作出书面检查。',
#   '在武义县纪委监委督促指导下，该中心建立了常态化内部监督机制，通过明察暗访、问卷调查等形式，重点对群众反映的热线接待忙、办事效率低、服务态度差等痛点问题开展自查，并动态跟踪整改落实情况。',
#   '热线的区城运中心对接，联手查找问题工单，对不作为、慢作为和乱作为问题严肃查处、开展问责。',
#   '次，造成不良影响，进行全县通报批评。”',
#   '近日，一份《关于推诿扯皮未严格落实“首接负责制”处置市民热线的情况通报》在山东省阳谷县各级党组织和党员干部中引发关注。',
#   '市民热线办理工作制度》、督促县综合执法局印发通知进一步明确市民热线办理工作、督促县公安局建立了市民热线工作服务流程和考核细则。'],
#  ['公司控股股东、实控人，原董事长刘群涉嫌生产、销售假药罪、职务侵占罪、挪用资金罪、虚假诉讼罪及公司原总经理李洪涉嫌生产、销售假药罪、职务侵占罪、挪用资金罪一案，由重庆市公安局侦查终结，移送重庆一分检审查起诉。',
#   '万元。',
#   '重庆一分检认为，刘群及被告单位天圣制药的上述行为应当以涉嫌单位行贿罪和对单位行贿罪追究刑事责任。',
#   '重庆一分检认为，刘群和李洪的上述行为应当以职务侵占罪和挪用资金罪追究其刑事责任。',
#   '重庆一分检认为，刘群的上述行为应当以虚假诉讼罪追究其刑事责任。',
#   '者单处罚金。'],
#  ['日，随着企业复工复产进程加快，中欧班列（苏州）迎来全面复苏，并反超去年同期。',
#   '。',
#   '。',
#   '月的苏州中欧班列是国内市场化程度最高的中欧班列，现已发展形成集中欧、中亚、中俄进出口班列于一体的国际铁路货运体系。',
#   '。',
#   '列进口的频次。',
#   '条措施，实行“不见面”审批制度，依托国际贸易“单一窗口”全面实现中欧班列进出口货物通关流程信息化、无纸化，优化作业流程，助力中欧班列跑出逆势增长“加速度”。',
#   '家生产企业通过中欧班列进出口货物。'],
#  ['近年来，为支持扶贫开发，增减挂钩政策先后两次拓展范围，允许集中连片特困地区、国家级贫困县、以及省级贫困县的节余指标在省域内流转使用，为贫困地区脱贫攻坚拓展了资金来源。',
#   '记者了解到，该政策支持脱贫攻坚工作主要体现在有力保障云南省易地扶贫搬迁安置用地的同时，允许节余指标在省内、省外有偿流转使用，为云南省脱贫攻坚筹措“真金白银”，从而在保障用地和筹措资金两方面强力支持脱贫攻坚工作。',
#   '近年来，云南省增减挂钩支持脱贫攻坚工作取得了长足发展。',
#   '万亩城市基础设施、经营性项目及产业发展用地。',
#   '亿元资金，有力支撑了各地脱贫攻坚工作。',
#   '下一步，云南省自然资源厅将进一步强化抓落实、扎实推进云南省城乡建设用地增减挂钩工作，继续坚持“挂图督战”行动，加大奖惩力度，保质保量按时完成工作任务，为云南省巩固拓展脱贫攻坚成果、全面推进乡村振兴提供有力保障。'],
#  ['智能机床核心技术后，沈阳机床终于突破老国企转型坚冰。',
#   '更严重的是，那时的沈阳机床虽是行业“巨无霸”，但同许多机床企业一样，并不掌握核心技术，每台机床搭载的数控系统，主要依赖从日本发那科和德国西门子进口。',
#   '智能机床，实现人机、物机实时连接。',
#   '沈阳机床开始从单一的机床制造商向新型工业服务商转型。',
#   '技术创新，打破了日本发那科、德国西门子两大巨头的长期垄断，实现了互联网条件下工业化、信息化、网络化、智能化的有效集成，为企业结构调整和转型升级杀出一条新路。',
#   '分享式平台，对外提供技术服务，助力智造新变革。'],
#  ['会议强调，越是在疫情防控形势持续向好的时候，越要增强忧患意识，对疫情的警惕性不能降低，防控要求不能降低，慎终如始、毫不放松加强疫情防控工作。',
#   '克服疫情不利影响，通过多种形式开展调查研究，充分运用视频监控和大数据、云计算等信息化手段，加强点上情况收集、加强上下互动、加强典型案例剖析、加强面上数据研判，真正摸清情况、找准问题、找准对策。',
#   '各地疫情不同，服务安全生产的方法手段不能千篇一律，要坚持“一厂一策”，“小火用灭火器、大火用水龙头”，加强精准执法，实施有效监管。',
#   '复工复产要“合格一批、复产一批”，安全检查要“发现问题、解决问题”，存在重大隐患和发生事故的要“一事一处理”，严防一罚了之、一停了之。',
#   '对易引发群死群伤的企业和场所，特别是高瓦斯、冲击地压、大班次等煤矿，大型油气储存、有毒有害等化工装置，医院、养老等人员密集场所，要现场检查、网上巡查，对不放心的要加强派驻督办、死看死守，坚决防范遏制重特大事故。',
#   '逐项落实国办进一步精简审批优化服务精准稳妥推进企业复工复产十项措施和应急管理部统筹推进企业安全防范和复工复产八项措施，加强督查督办，确保便民惠企措施落到实处，让企业和群众真正有获得感。'],
#  ['）。',
#   '技术平台实力的试金石。',
#   '个单抗药物进入从药物发现到临床三期等不同里程碑阶段。',
#   '能力，形成了具有核心竞争力的抗体药物研发平台。',
#   '细胞抗体研发服务的一站式研发外包服务机构。',
#   '量子生物方面表示，“浦东新区营运总部”的认定，使得上海睿智在政府的创新驱动政策支持下和财政扶持下，可以集中更多精力提高自身的核心竞争力、扩大产能为加速医药创新贡献力量。'],
#  ['百年征程波澜壮阔，百年初心历久弥坚，百年大党何以永远年轻，关键在于弘扬光荣传统、赓续红色血脉，永远把伟大建党精神继承下去、发扬光大。',
#   '），就是要坚定‘一定要把民族汽车品牌搞上去’的决心，坚定向智能低碳出行科技公司转型。”',
#   '长安汽车党委书记、董事长朱华荣在接受《》记者采访时表示。',
#   '万辆的中国品牌，有力推进中国汽车工业的发展。',
#   '年是国企改革三年行动的攻坚之年、关键之年，长安汽车深入开展国企改革三年行动，坚决落实党中央的系列决策部署，融入公司战略、自主创新、高质量发展等具体工作中。',
#   '构建中国特色现代企业制度，全面落实党委“把方向、管大局、促落实”领导作用，厘清各治理主体的决策事项和权责边界。',
#   '强化技术引领，加强“芯屏器核图网天”技术储备，推动“中国芯”工程等，全力突破“卡脖子”技术，着力打造自主可控、安全可靠的产业链、供应链。',
#   '创新人才培养模式，持续构建三级后备干部梯队，实施“头鲸计划”，为战略发展提供强有力的人才保障，建设技能大师工作室，促进高技能人才培养与技术技能攻关相融合。'],
#  ['现在，和巨量引擎这样多数具备流量优势的平台，都在思考如何运用流量和技术，对用户进行画像归类，进而实现精准营销，形成更好的广告效果转化，汽车行业亦是如此，甚至可以说新的时代对汽车营销提出了新的考验。',
#   '用户精耕时代，随着私域流量价值的提升，巨量引擎也在不断打磨阵地经营产品，建立了企业号、品牌号、机构号等一体的品牌营销阵地，让品牌可以实现从内容创作、流量获取、营销转化、长效经营到关系沉淀。',
#   '在品牌关系用户经营上，巨量引擎采用“营销双引擎”，即心智引擎和行动引擎，构建真实有效的营销体系，激发增量促进转化。',
#   '巨量引擎云图可以实现对品牌关系用户进行精细化经营，包括从营销策略、应用场景到价值评估，全链路用户管理，清晰明白哪些是感知用户、哪些是好奇用户等等，从而能更好进行营销决策。',
#   '在通过“品牌营销”、“品效协同”、“效果营销”三个维度来科学解构营销战术，激发用户兴趣，促进用户行为，实现营销增量和转化。',
#   '”营销方法论，将科学评估体系渗入营销活动每一环，可全面衡量营销活动效果，并指导营销优化形成营销闭环。'],
#  ['股权。',
#   '拟设立子公司青岛西海新材料科技有限公司经营范围：石油化工技术的研究开发、技术服务、技术转让。',
#   '。',
#   '。',
#   '。',
#   '石油化工技术、化工固废、危废环保技术、化工环保技术的研究开发、技术咨询服务、技术转让。'],
#  ['近日，在长三角区域合作办公室的组织下，上海申铁投资有限公司、上海申通地铁集团有限公司和江苏省发改委、江苏省铁路办等相关负责人组成调研组，专程至江苏太仓调研，对接嘉闵线北延伸段一体化建设运营相关问题。',
#   '调研组一行实地考察了沪苏通铁路太仓站、岳鹿路对接嘉定城北路段的现场情况，听取了太仓市推进苏锡常城际铁路与上海嘉闵线对接先导段建设的情况汇报。',
#   '座车站，分别为城北路站、新成路站、嘉戬公路站、丰茂路站、南翔站、金园五路站、金运路站、天山路站、虹桥站、迎宾三路站、沪星路站、七宝站、七莘路站、莘建路站和银都路站（站名均为暂命名）。',
#   '经过的主要区域有嘉定新城、南翔、江桥、虹桥商务区、七宝、莘庄等，可与多条上海轨道交通线路换乘。',
#   '申铁公司副总经理胡光祥表示，上海市域铁路考虑了与国铁、城际、市域铁路自身三个层次的互联互通，嘉闵线具备向北、向南延伸的条件。',
#   '与会代表们经过充分讨论研究，一致认为：为加快建设“轨道上的长三角”，推进嘉闵线北延伸段工程的跨省跨界互联互通十分紧要、十分必要。']]

# %%
assert 1

# %%
assert (1==1)+(0==1)

# %%
assert -1

# %%
import numpy as np

# %%
for i in range(5):
    a = np.random.randn(10,512,7) 
    b = np.random.randn(10,512)
    np.savez("/home/yuxin.fan/data_for_test/file{}.npz".format(i+1),a=a,b=b)

# %%
from extract_summary_finetune.news_to_summary import NewsToSummary

# %%
text = '''佩洛西的访问之行在连续多天成为国际间揣测的话题，但直至最后一刻之前仍然充满谜团
她的亚洲之行在周日启程时，在官方行程单上并没有提及台湾，只包括了新加坡、马来西亚、韩国和日本
白宫一直公开反对此次访台之行，总统拜登表示，美国军方认为此行“不是一个好主意”。
但在佩洛西抵达之后，白宫的发言人柯比向美国有线电视新闻网（CNN）表示，此行与过去其他官员的访问类似。
“没有理由让此行引发冲突。我们的政策没有改变。这与政策是绝对一致的。”
在谈到中国的强烈反应时，他表示：“美国不会被威吓所胁迫。”
BBC记者沙磊（John Sudworth）在华盛顿报道，有迹象显示，佩洛西此行得到了两党支持，包括来自共和党的反对者，他们通常不会将自己列为佩洛西的支持者。
最近一个支持的反对阵营政客、共和党参议员丹·沙利文（Dan Sullivan）表示：“你不想中国共产党来主宰美国领导人能去哪里，不能去哪里。'''

# %%
a = NewsToSummary(network="transformer1",bert="wwm_bert",loss="BCEloss",
                  text=text)
# Out:
# Some weights of the model checkpoint at hfl/chinese-roberta-wwm-ext-large were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
a.summary_modified[0]
# Out:
# '佩洛西的访问之行在连续多天成为国际间揣测的话题，但直至最后一刻之前仍然充满谜团\n她的亚洲之行在周日启程时，在官方行程单上并没有提及台湾，只包括了新加坡、马来西亚、韩国和日本\n\n白宫一直公开反对此次访台之行'

# %%
'''佩洛西的访问之行在连续多天成为国际间揣测的话题，但直至最后一刻之前仍然充满谜团
她的亚洲之行在周日启程时，在官方行程单上并没有提及台湾，只包括了新加坡、马来西亚、韩国和日本

白宫一直公开反对此次访台之行，总统拜登表示，美国军方认为此行“不是一个好主意”。

但在佩洛西抵达之后，白宫的发言人柯比向美国有线电视新闻网（CNN）表示，此行与过去其他官员的访问类似。

“没有理由让此行引发冲突。我们的政策没有改变。这与政策是绝对一致的。”

在谈到中国的强烈反应时，他表示：“美国不会被威吓所胁迫。”

BBC记者沙磊（John Sudworth）在华盛顿报道，有迹象显示，佩洛西此行得到了两党支持，包括来自共和党的反对者，他们通常不会将自己列为佩洛西的支持者。

最近一个支持的反对阵营政客、共和党参议员丹·沙利文（Dan Sullivan）表示：“你不想中国共产党来主宰美国领导人能去哪里，不能去哪里。'''

# %% [markdown]
# <span style="font-size:24px;"><html>
# 	<head>
# 		<title>
# 			行间距
# 		</title>
# 		<style>
# 			<!--
# 			p.one{
# 			font-size:10pt;
# 			line-height:8pt;
# 		}
# 			p.second{
# 			font-size:18px;
# 		}
# 			p.third{font-size:10px;
# 		}
# 			p.second,p.third{
# 			line-height:1.5em;
# 		}
# 			-->
# 		</style>
# 	</head>
#
# 	<body>
# 		<p class="one">9月23日是“秋分”，我国古籍《春秋繁露、阴阳出入上下篇》中说：“秋分者，阴阳相半也，故昼夜均而寒暑平。”“秋分”的意思有二：一是太阳在这时到达黄径180.一天24小时昼夜均分，各12小时；二是按我国古代以立春、立夏、立秋、立冬为四季开始的季节划分法，秋分日居秋季90天之中，平分了秋季。</p>
# 		<p class="second">秋分时节，我国常见流域及其以北的广大地区，均夏侯进入了秋季，日平均气温都降到了22℃以下。北方冷气团开始具有一定的势力，大部分地区雨季刚刚结束，凉风习习，碧空万里，风和日丽，秋高气爽，丹桂飘香，蟹肥橘黄，秋分是美好宜人的时节。</p>
# 		<p class="third">秋季降温快的特点，使得秋收、秋耕、秋种的“三秋”大忙显得格外紧张。秋分棉花吐絮，烟叶也由绿变黄，正是收获的大好时机。华北地区已开始播种冬麦，长江流域及南部广大地区正忙着晚稻的收割，抢晴耕翻土地，准备油菜播种。</p>
# 	</body>
# </html>
# </span>
